# %% [markdown]
# ### 이미지 수집하기

# %%
import requests 
from bs4 import BeautifulSoup
code = requests.get("http://www.cgv.co.kr/movies/?It=1&ft=0")
soup = BeautifulSoup(code.text,"html.parser")
title_elements = soup.select("strong.title")
image_elements = soup.select("span.thumb-image>img")
percent_elements = soup.select("strong.percent > span")
date_elements = soup.select("span.txt-info > strong")
for title, image, percent, date in zip(title_elements,image_elements, percent_elements, date_elements):
    print(f"제목:{title.text}")
    print(f"예매율:{percent.text}")
    print(f"개봉일:{date.text.strip()[:10]}")
    print(image)
    print("-----------------------------")
# Out:
# 제목:글래디에이터 Ⅱ
# 예매율:17.3%
# 개봉일:2024.11.13
# <img alt="글래디에이터 Ⅱ 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88459/88459_320.jpg"/>
# -----------------------------
# 제목:청설
# 예매율:16.0%
# 개봉일:2024.11.06
# <img alt="청설 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88847/88847_320.jpg"/>
# -----------------------------
# 제목:아마존 활명수
# 예매율:10.9%
# 개봉일:2024.10.30
# <img alt="아마존 활명수 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88539/88539_320.jpg"/>
# -----------------------------
# 제목:레드 원
# 예매율:8.1%
# 개봉일:2024.11.06
# <img alt="레드 원 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88922/88922_320.jpg"/>
# -----------------------------
# 제목:사흘
# 예매율:6.0%
# 개봉일:2024.11.14
# <img alt="사흘 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88909/88909_320.jpg"/>
# -----------------------------
# 제목:베놈: 라스트 댄스
# 예매율:5.5%
# 개봉일:2024.10.23
# <img alt="베놈: 라스트 댄스 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88526/88526_320.jpg"/>
# -----------------------------
# 제목:위키드
# 예매율:5.3%
# 개봉일:2024.11.20
# <img alt="위키드 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88076/88076_320.jpg"/>
# -----------------------------
# 제목:롱레그스
# 예매율:2.7%
# 개봉일:2024.10.30
# <img alt="롱레그스 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88659/88659_320.jpg"/>
# -----------------------------
# 제목:아메바 소녀들과 학교괴담-개교기념일
# 예매율:2.4%
# 개봉일:2024.11.06
# <img alt="아메바 소녀들과 학교괴담-개교기념일 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88876/88876_320.jpg"/>
# -----------------------------
# 제목:(라이브뷰잉) 앙상블 스타즈!! 드림라이브 9th 투어 - Trapezium #Orion
# 예매율:2.4%
# 개봉일:2024.11.22
# <img alt="(라이브뷰잉) 앙상블 스타즈!! 드림라이브 9th 투어 - Trapezium #Orion 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88993/88993_320.jpg"/>
# -----------------------------
# 제목:괴물
# 예매율:2.3%
# 개봉일:2024.11.07
# <img alt="괴물 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000087/87716/87716_320.jpg"/>
# -----------------------------
# 제목:아노라
# 예매율:2.0%
# 개봉일:2024.11.06
# <img alt="아노라 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88838/88838_320.jpg"/>
# -----------------------------
# 제목:빌리와 용감한 녀석들-스노우 베어 구조대
# 예매율:2.0%
# 개봉일:2024.11.07
# <img alt="빌리와 용감한 녀석들-스노우 베어 구조대 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88812/88812_320.jpg"/>
# -----------------------------
# 제목:보통의 가족
# 예매율:1.6%
# 개봉일:2024.10.16
# <img alt="보통의 가족 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88688/88688_320.jpg"/>
# -----------------------------
# 제목:크레센도
# 예매율:1.0%
# 개봉일:2024.11.06
# <img alt="크레센도 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000087/87873/87873_320.jpg"/>
# -----------------------------
# 제목:리틀 엠마
# 예매율:0.9%
# 개봉일:2024.10.25
# <img alt="리틀 엠마 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88813/88813_320.jpg"/>
# -----------------------------
# 제목:대도시의 사랑법
# 예매율:0.8%
# 개봉일:2024.10.01
# <img alt="대도시의 사랑법 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88538/88538_320.jpg"/>
# -----------------------------
# 제목:날씨의 아이
# 예매율:0.8%
# 개봉일:2024.10.30
# <img alt="날씨의 아이 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000087/87033/87033_320.jpg"/>
# -----------------------------
# 제목:플로리다 프로젝트
# 예매율:0.7%
# 개봉일:2018.03.07
# <img alt="플로리다 프로젝트 포스터" onerror="errorImage(this)" src="https://img.cgv.co.kr/Movie/Thumbnail/Poster/000080/80500/80500_320.jpg"/>
# -----------------------------

# %%
import requests 
from bs4 import BeautifulSoup
code = requests.get("http://www.cgv.co.kr/movies/?It=1&ft=0")
soup = BeautifulSoup(code.text,"html.parser")
title_elements = soup.select("strong.title")
image_elements = soup.select("span.thumb-image>img")
percent_elements = soup.select("strong.percent > span")
date_elements = soup.select("span.txt-info > strong")
for title, image, percent, date in zip(title_elements,image_elements,percent_elements,date_elements):
    print(f"제목:{title.text}")
    print(f"예매율:{percent.text}")
    print(f"개봉일:{date.text.strip()[:10]}")
    print(image.attrs["src"])
    print("-----------------------------")
# Out:
# 제목:글래디에이터 Ⅱ
# 예매율:17.3%
# 개봉일:2024.11.13
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88459/88459_320.jpg
# -----------------------------
# 제목:청설
# 예매율:16.0%
# 개봉일:2024.11.06
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88847/88847_320.jpg
# -----------------------------
# 제목:아마존 활명수
# 예매율:10.9%
# 개봉일:2024.10.30
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88539/88539_320.jpg
# -----------------------------
# 제목:레드 원
# 예매율:8.1%
# 개봉일:2024.11.06
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88922/88922_320.jpg
# -----------------------------
# 제목:사흘
# 예매율:6.0%
# 개봉일:2024.11.14
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88909/88909_320.jpg
# -----------------------------
# 제목:베놈: 라스트 댄스
# 예매율:5.5%
# 개봉일:2024.10.23
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88526/88526_320.jpg
# -----------------------------
# 제목:위키드
# 예매율:5.3%
# 개봉일:2024.11.20
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88076/88076_320.jpg
# -----------------------------
# 제목:롱레그스
# 예매율:2.7%
# 개봉일:2024.10.30
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88659/88659_320.jpg
# -----------------------------
# 제목:아메바 소녀들과 학교괴담-개교기념일
# 예매율:2.4%
# 개봉일:2024.11.06
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88876/88876_320.jpg
# -----------------------------
# 제목:(라이브뷰잉) 앙상블 스타즈!! 드림라이브 9th 투어 - Trapezium #Orion
# 예매율:2.4%
# 개봉일:2024.11.22
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88993/88993_320.jpg
# -----------------------------
# 제목:괴물
# 예매율:2.3%
# 개봉일:2024.11.07
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000087/87716/87716_320.jpg
# -----------------------------
# 제목:아노라
# 예매율:2.0%
# 개봉일:2024.11.06
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88838/88838_320.jpg
# -----------------------------
# 제목:빌리와 용감한 녀석들-스노우 베어 구조대
# 예매율:2.0%
# 개봉일:2024.11.07
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88812/88812_320.jpg
# -----------------------------
# 제목:보통의 가족
# 예매율:1.6%
# 개봉일:2024.10.16
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88688/88688_320.jpg
# -----------------------------
# 제목:크레센도
# 예매율:1.0%
# 개봉일:2024.11.06
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000087/87873/87873_320.jpg
# -----------------------------
# 제목:리틀 엠마
# 예매율:0.9%
# 개봉일:2024.10.25
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88813/88813_320.jpg
# -----------------------------
# 제목:대도시의 사랑법
# 예매율:0.8%
# 개봉일:2024.10.01
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000088/88538/88538_320.jpg
# -----------------------------
# 제목:날씨의 아이
# 예매율:0.8%
# 개봉일:2024.10.30
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000087/87033/87033_320.jpg
# -----------------------------
# 제목:플로리다 프로젝트
# 예매율:0.7%
# 개봉일:2018.03.07
# https://img.cgv.co.kr/Movie/Thumbnail/Poster/000080/80500/80500_320.jpg
# -----------------------------

# %%
import requests 
from bs4 import BeautifulSoup
import urllib.request as req
import os
import openpyxl
from openpyxl.drawing.image import Image
from PIL import Image as PILImage
#엑셀파일 생성
book = openpyxl.Workbook()
sheet = book.active
code = requests.get("http://www.cgv.co.kr/movies/?It=1&ft=0")
soup = BeautifulSoup(code.text,"html.parser")
title_elements = soup.select("strong.title")
image_elements = soup.select("span.thumb-image>img")
percent_elements = soup.select("strong.percent > span")
date_elements = soup.select("span.txt-info > strong")
# 이미지 내려받을 폴더 생성
folder_name="./CGV 무비차트 포스터"
if not os.path.exists(folder_name):
    os.mkdir(folder_name)
num = 1
for title, image, percent, date in zip(title_elements,image_elements,percent_elements,date_elements):
    print(f"제목:{title.text}")
    print(f"예매율:{percent.text}")
    print(f"개봉일:{date.text.strip()[:10]}")
    img_url = image.attrs["src"]
    req.urlretrieve(img_url,f"{folder_name}/{num}.jpg")
    #이미지 크기 조절
    img = PILImage.open(f"{folder_name}/{num}.jpg")
    img_resized = img.resize((int(img.width*0.3),int(img.height * 0.3)))
    img_resized.save(f"{folder_name}/{num}_resized.jpg")
    img.close()
    # 엑셀에 이미지 첨부
    sheet.add_image(Image(f"{folder_name}/{num}_resized.jpg"), f"A{num}")
    #엑셀 시트에 영화제목, 예매율, 개봉일 기록
    sheet.cell(row=num, column=2).value = title.text
    sheet.cell(row=num, column=3).value = percent.text
    sheet.cell(row=num, column=4).value = date.text.strip()[:10]
    #행의 높이 조절
    sheet.row_dimensions[num].height = 197
    num += 1
    print("-----------------------------")
    #열 너비 조절
    sheet.column_dimensions["A"].width = 23
    sheet.column_dimensions["B"].width = 35
    sheet.column_dimensions["C"].width = 15
    sheet.column_dimensions["D"].width = 21
    
    book.save("./CGV_무비차트.xlsx")
# Out:
# 제목:글래디에이터 Ⅱ
# 예매율:17.3%
# 개봉일:2024.11.13
# -----------------------------
# 제목:청설
# 예매율:16.0%
# 개봉일:2024.11.06
# -----------------------------
# 제목:아마존 활명수
# 예매율:10.9%
# 개봉일:2024.10.30
# -----------------------------
# 제목:레드 원
# 예매율:8.1%
# 개봉일:2024.11.06
# -----------------------------
# 제목:사흘
# 예매율:6.0%
# 개봉일:2024.11.14
# -----------------------------
# 제목:베놈: 라스트 댄스
# 예매율:5.5%
# 개봉일:2024.10.23
# -----------------------------
# 제목:위키드
# 예매율:5.3%
# 개봉일:2024.11.20
# -----------------------------
# 제목:롱레그스
# 예매율:2.7%
# 개봉일:2024.10.30
# -----------------------------
# 제목:아메바 소녀들과 학교괴담-개교기념일
# 예매율:2.4%
# 개봉일:2024.11.06
# -----------------------------
# 제목:(라이브뷰잉) 앙상블 스타즈!! 드림라이브 9th 투어 - Trapezium #Orion
# 예매율:2.4%
# 개봉일:2024.11.22
# -----------------------------
# 제목:괴물
# 예매율:2.3%
# 개봉일:2024.11.07
# -----------------------------
# 제목:아노라
# 예매율:2.0%
# 개봉일:2024.11.06
# -----------------------------
# 제목:빌리와 용감한 녀석들-스노우 베어 구조대
# 예매율:2.0%
# 개봉일:2024.11.07
# -----------------------------
# 제목:보통의 가족
# 예매율:1.6%
# 개봉일:2024.10.16
# -----------------------------
# 제목:크레센도
# 예매율:1.0%
# 개봉일:2024.11.06
# -----------------------------
# 제목:리틀 엠마
# 예매율:0.9%
# 개봉일:2024.10.25
# -----------------------------
# 제목:대도시의 사랑법
# 예매율:0.8%
# 개봉일:2024.10.01
# -----------------------------
# 제목:날씨의 아이
# 예매율:0.8%
# 개봉일:2024.10.30
# -----------------------------
# 제목:플로리다 프로젝트
# 예매율:0.7%
# 개봉일:2018.03.07
# -----------------------------

# %% [markdown]
# ### 1분 퀴즈 풀어보기 [p.244]
# #### 6. 다음 설명 중 옳은 것을 고르세요
# ##### 1. sheet.cell(row=1,column=2).value = "Hello"는 엑셀의 1행 C열에 값을 입력하는 코드이다.
# ##### 2. sheet.column_dimensions["A"].width = 23은 A열의 너비를 23으로 설정하는 코드이다.
# ##### 3. sheet.row_dimensions[10].height = 197은 10열의 너비를 197로 설정하는 코드이다.
# ##### 4. sheet.add_image("image.jpg","A1")은 image.jpg의 크기를 A1 셀에 맞게 조절하는 코드이다.
#
# ###### 정답 : 2
# ###### 해설 :
# ###### 1번은 행번호1번, 열번호2번에 해당하는 셀에 Hello라는 문장을 입력하라는 코드이다. 즉 1행 C열이 아닌 1행 B열에 값을 입력하는 코드이므로 1번은 정답이 아니다.
# ###### 3번은 열의 너비를 조절하는 것이 아닌 행10번에 높이를 197로 설정하는 코드이므로 3번은 정답이 아니다.
# ###### 4번은 이미지의 크기를 해당 셀에 맞게 조절하는 코드가 아닌 해당 셀에 이미지를 첨부하는 코드이므로 4번은 정답이 아니다.
