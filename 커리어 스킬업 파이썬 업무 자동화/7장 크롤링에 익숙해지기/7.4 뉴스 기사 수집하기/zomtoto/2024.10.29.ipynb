# %%
import requests
from bs4 import BeautifulSoup
code = requests.get(f"https://underkg.co.kr/news")
soup = BeautifulSoup(code.text, "html.parser")
title = soup.select("h1.title>a")
for i in title:
    print(f"제목 : {i.text}")
    news_url = i.attrs['href']
    print(f"링크 : {news_url}")
    code_news = requests.get(news_url)
    soup_news = BeautifulSoup(code_news.text, "html.parser")
    content = soup_news.select_one("div.read_body")
    print(content.text.replace("\n","").strip())
    print("-------------------------------------------")
# Out:
# 제목 : 삼성전자, ‘삼성 개발자 콘퍼런스 코리아 2024’ 11월 개최
# 링크 : http://underkg.co.kr/news/2942067
# ...

# %% [markdown]
# ### 1분 퀴즈 풀어보기 [p.227]
# #### 4. `<input name = "user">` 요소가 foo변수에 저장돼 있습니다. foo 변수를 이용해 `<input>`요소의 name속성값을 가져오는 명령을 고르세요.
#
# #### 1.foo["name"]
# #### 2.foo.attrs["name"]
# #### 3.foo.text["name"]
# #### 4.foo.attrs["name"]
# ##### 정답 : 2
# ##### 해설 :  attrs는 모든 속성을 딕셔너리 형태로 저장하기 때문에 name 속성값을 가져오기 위해서는 attrs["속성이름"]을 사용하여야 한다 그러므로 정답은 2번이다
