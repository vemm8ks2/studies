# %%
import time 
from selenium import webdriver
from selenium.webdriver.common.by import By

keyword = input("상품 입력 >> ")

opt = webdriver.ChromeOptions()
opt.add_experimental_option("detach",True)
browser = webdriver.Chrome(options=opt)
browser.get(f"https://www.lotteimall.com/search/searchMain.lotte?slog=00101_1&headerQuery={keyword}")
time.sleep(3)
name = browser.find_elements(By.CSS_SELECTOR, "p.title>a")
for i in name:
    print(i.text)

browser.close()
# Out:
# 상품 입력 >>  빼빼로
# [롯데웰푸드] 아이러브 빼빼로 16개(초코9개+아몬드7개)
# [롯데웰푸드] 2024 뉴진스 빼빼로 8입 2개+10입 1개 3SET 골라담기
# [디씽컴퍼니] 아몬드 빼빼로 10개 SET x4개
# [롯데웰푸드] 아몬드 빼빼로 32g X10개
# [롯데웰푸드] 2024 뉴진스빼빼로 10갑 케이크
# [롯데웰푸드] 혼합 빼빼로10갑 SET (초코4갑+아몬드3갑+초코필드3갑)
# [롯데웰푸드] 빼빼로 샘플러 6입X4개
# [디씽컴퍼니] 누드 초코필드 빼빼로 10개 SET x4개
# [롯데웰푸드] 빼빼로 씨리얼 롱 세트(10개입) X3통
# [롯데웰푸드] 롯데웰푸드 남해 유자 빼빼로 37g x 10개
# [롯데웰푸드] 2024 뉴진스 초코빼빼로 8갑 + 아몬드빼빼로 8갑 + 크런키빼빼로 8갑
# [롯데웰푸드] 2024 뉴진스 아몬드빼빼로 8갑
# [롯데웰푸드] 2024 뉴진스 초코빼빼로 8갑
# [디씽컴퍼니] 누드 초코필드 빼빼로 10개 SET
# [롯데웰푸드] 빼빼로 샘플러 6입X2개
# [롯데웰푸드] 2024 뉴진스 크런키빼빼로 8갑
# [롯데웰푸드] 2024 뉴진스 빼빼로 초코 8갑+아몬드 8갑+크런키 8갑+화이트쿠키 8갑
# [디씽컴퍼니] 누드 초코필드 빼빼로 45g X40개
# [롯데웰푸드] 빼빼로 3종 30개 세트 (초코x10개+아몬드x10개+누드10개)
# [롯데]빼빼로 6종 세트 664g
# [롯데웰푸드] 혼합 빼빼로10갑 SET (초코4갑+아몬드3갑+초코필드3갑) x2개
# [롯데웰푸드] 아몬드 빼빼로 32gX10개+초코필드 빼빼로 45gX10개
# [롯데웰푸드] 초코필드 빼빼로 45g X35개
# [글로벌푸드] 롯데 초코 빼빼로 54g x 8 / 빼빼로데이
# [롯데웰푸드] 초코 빼빼로 46gX10개+아몬드 빼빼로 32gX10개
# [롯데웰푸드] 초코필드 빼빼로 45g X30개
# [롯데웰푸드] 혼합빼빼로 10갑 SET(초코4아몬드3누드3)+누드 빼빼로 10갑 SET
# ...

# %% [markdown]
# ### 1분 퀴즈 풀어보기 [p.265]
# #### 2. selenium 모듈에 대한 설명 중 옳은 것을 고르세요.
# ##### 1. bs4 모듈보다 크롤링 속도가 빠르다.
# ##### 2. selenium 모듈은 버튼을 자동으로 클릭하지 못한다.
# ##### 3. bs4모듈의 select()와 selenium모듈의 find_element()는 같은 기능을 한다.
# ##### 4. bs4 모듈로 크롤링을 시도했을 때 결과가 나오지 않으면 selenium 모듈을 이용한다.
#
# ###### 정답 : 4
# ###### 해설 : 1. bs4모듈이 제대로 동작만 한다면 selenium모듈모다 속도가 더 빠르다.
# ###### 2. selenium모듈은 자동으로 버튼을 클릭하는 기능을 가지고 있다.
# ###### 3. select()와 find_element()는 같은 기능을 하지 않음.
