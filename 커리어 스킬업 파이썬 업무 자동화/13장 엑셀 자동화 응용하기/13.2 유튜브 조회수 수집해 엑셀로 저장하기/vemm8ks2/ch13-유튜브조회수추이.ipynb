# %% [markdown]
# ### 유튜브 조회수 수집해 엑셀로 저장하기 (13.2)

# %%
import time
from selenium import webdriver
from selenium.webdriver import ActionChains, Keys
from selenium.webdriver.common.by import By

# %%
import os
import openpyxl
import datetime

# %%
from openpyxl.chart import LineChart, Reference

# %%
from openpyxl.styles import Font, Alignment, PatternFill, Border, Side

# %%
def string_to_integer(view):
    if "만회" in view:
        view = view.replace("만회", "")
        view = int(float(view) * 10000)
    elif "천회" in view:
        view = view.replace("천회", "")
        view = int(float(view) * 1000)
    elif "회" in view:
        view = view.replace("회", "")
        view = int(view)
    return view

# %%
# 유튜브 조회수 수집하기 (13.2.1)
def crawling(reverse = False):
    # 유튜브 접속
    opt = webdriver.ChromeOptions()
    opt.add_experimental_option('detach', True)
    browser = webdriver.Chrome(options=opt)
    browser.get('https://www.youtube.com/@nadocoding/videos')
    time.sleep(3)
    
    # 스크롤 끝까지 내리기
    same_num_cnt = 0
    prev_height = 0
    
    while True:
        ActionChains(browser).key_down(Keys.PAGE_DOWN).perform()
        cur_height = browser.execute_script("return document.documentElement.scrollTop")
    
        if prev_height == cur_height:
            same_num_cnt += 1
        else:
            same_num_cnt = 0
    
        if same_num_cnt == 200:
            break
    
        prev_height = cur_height
        
    # 크롤링
    if reverse:
        title_elements = reversed(browser.find_elements(By.CSS_SELECTOR, "#contents #video-title"))
        views_elements = reversed(browser.find_elements(By.CSS_SELECTOR, "span.inline-metadata-item.style-scope.ytd-video-meta-block:nth-child(3)"))
        date_elements = reversed(browser.find_elements(By.CSS_SELECTOR, "span.inline-metadata-item.style-scope.ytd-video-meta-block:nth-child(4)"))
        link_elements = reversed(browser.find_elements(By.CSS_SELECTOR, "a#video-title-link"))
    else:
        title_elements = browser.find_elements(By.CSS_SELECTOR, "#contents #video-title")
        views_elements = browser.find_elements(By.CSS_SELECTOR, "span.inline-metadata-item.style-scope.ytd-video-meta-block:nth-child(3)")
        date_elements = browser.find_elements(By.CSS_SELECTOR, "span.inline-metadata-item.style-scope.ytd-video-meta-block:nth-child(4)")
        link_elements = browser.find_elements(By.CSS_SELECTOR, "a#video-title-link")

    # 유튜브 조회수 엑셀로 저장하기 (13.2.2)
    ## 엑셀 파일 생성
    if not os.path.exists("./유튜브채널조회수"):
        os.mkdir("./유튜브채널조회수")

    book = openpyxl.Workbook()
    sheet = book.active

    sheet.cell(row=1, column=1).value = "영상 제목"
    sheet.cell(row=1, column=2).value = "조회수"
    sheet.cell(row=1, column=3).value = "업로드 날짜"
    sheet.cell(row=1, column=4).value = "영상 링크"

    sheet.column_dimensions["A"].width = 85
    sheet.column_dimensions["B"].width = 10
    sheet.column_dimensions["C"].width = 13
    sheet.column_dimensions["D"].width = 50

    row_num = 2
    
    # 결과 출력
    for view, date, title, link in zip(views_elements, date_elements, title_elements, link_elements):
        view_integer = string_to_integer(view.text.replace("조회수 ", ""))
        video_link = link.get_attribute("href")
        print(f"|| --- 영상 제목 : {title.text}")
        print(f"|| --- 조회수 : {view_integer}")
        print(f"|| --- 업로드 날짜 : {date.text}")
        print(f"|| --- 링크 : {video_link}")
        print(f"||")

        sheet.cell(row=row_num, column=1).value = title.text
        sheet.cell(row=row_num, column=2).value = view_integer
        sheet.cell(row=row_num, column=3).value = date.text
        sheet.cell(row=row_num, column=4).value = video_link

        row_num += 1

    # 조회수 추이를 꺾은선 차트로 그리기 (13.2.3)
    ## 차트 생성
    chart = LineChart()

    chart.title = "조회수 추이"
    chart.style = 13
    chart.y_axis.title = "조회수"
    chart.x_axis.title = "영상 번호"
    
    data = Reference(sheet, range_string=f"Sheet!B1:B{sheet.max_row}")
    
    chart.add_data(data, titles_from_data=True)
    chart.width = 45
    chart.height = 25
    
    sheet.add_chart(chart, "E1")

    # 셀 서식 적용하기 (13.2.4)
    ## 서식 지정
    header_font = Font(bold=True, size=12)
    center_alignment = Alignment(horizontal="center")
    header_fill = PatternFill(start_color="D9EAF1", end_color="D9EAF1", patternType="solid")
    thin_border = Border(left=Side(style="thin"), right=Side(style="thin"), top=Side(style="thin"), bottom=Side(style="thin"))

    ## 제목 행 서식 적용
    for row in sheet["A1:D1"]:
        for cell in row:
            cell.font = header_font
            cell.alignment = center_alignment
            cell.fill = header_fill

    ## 데이터 부분 서식 적용
    for row in sheet["B2":f"D{sheet.max_row}"]:
        for cell in row:
            cell.alignment = center_alignment

    ## 영상 링크
    for row in sheet[f"D2:D{sheet.max_row}"]:
        for cell in row:
            cell.hyperlink = cell.value

    ## 모든 셀에 서식 적용
    for row in sheet.iter_rows():
        for cell in row:
            cell.border = thin_border

    today = datetime.datetime.today().strftime("%y%m%d_%H시%M분%S초")
    book.save(f"./유튜브채널조회수/{today}.xlsx")
    
    browser.close()

# %%
crawling()

# %% [markdown]
# ```
# || --- 영상 제목 : 챗GPT4o with Canvas 소개 - 글쓰기 및 코딩하시는 분들 꼭 보세요
# || --- 조회수 : 30000
# || --- 업로드 날짜 : 1개월 전
# || --- 링크 : https://www.youtube.com/watch?v=_QPdytD9yXY
# ||
# || --- 영상 제목 : 자바 무료 강의 2시간 완성 (1분 자바)
# || --- 조회수 : 50000
# || --- 업로드 날짜 : 6개월 전
# || --- 링크 : https://www.youtube.com/watch?v=DNCBaeCoMug
# ||
# || --- 영상 제목 : 새로운 시작, 코딩 공부와 함께 #유데미
# || --- 조회수 : 8600
# || --- 업로드 날짜 : 10개월 전
# || --- 링크 : https://www.youtube.com/watch?v=JhsrCJ_Hb84
# ||
#
# (중략)
# ```

# %%
crawling(True)

# %% [markdown]
# ```
# || --- 영상 제목 : (나도코딩 C) 소개
# || --- 조회수 : 110000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=dEykoFZkf5Y
# ||
# || --- 영상 제목 : (나도코딩 C) 1-1. 환경설정
# || --- 조회수 : 77000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=_jjZysGQS_w
# ||
# || --- 영상 제목 : (나도코딩 C) 1-2. Hello World
# || --- 조회수 : 61000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=xNMGGQIU8FU
# ||
#
# (중략)
# ```

# %%
crawling(True)
# Out:
# || --- 영상 제목 : (나도코딩 C) 소개
# || --- 조회수 : 110000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=dEykoFZkf5Y
# ||
# || --- 영상 제목 : (나도코딩 C) 1-1. 환경설정
# || --- 조회수 : 77000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=_jjZysGQS_w
# ||
# || --- 영상 제목 : (나도코딩 C) 1-2. Hello World
# || --- 조회수 : 61000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=xNMGGQIU8FU
# ||
# || --- 영상 제목 : (나도코딩 C) 2-8 프로젝트
# || --- 조회수 : 21000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=Ca_UCG40JX0
# ||
# || --- 영상 제목 : (나도코딩 C) 2-5 상수
# || --- 조회수 : 18000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=D4rZ7ZxxgAo
# ||
# || --- 영상 제목 : (나도코딩 C) 2-1 경찰서 조서 쓰기
# || --- 조회수 : 41000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=LF46oSNFP_U
# ||
# || --- 영상 제목 : (나도코딩 C) 2-4 실수형 변수
# || --- 조회수 : 21000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=PtUCr7a1dPo
# ||
# || --- 영상 제목 : (나도코딩 C) 2-7 scanf
# || --- 조회수 : 22000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=neFzhsdzI0Q
# ||
# || --- 영상 제목 : (나도코딩 C) 2-2 정수형 변수
# || --- 조회수 : 37000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=pQjUGIeSr3k
# ||
# || --- 영상 제목 : (나도코딩 C) 2-3 주석
# || --- 조회수 : 22000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=tqUVxNHeUys
# ||
# || --- 영상 제목 : (나도코딩 C) 2-6 printf
# || --- 조회수 : 19000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=wc3zH04hgBo
# ||
# || --- 영상 제목 : (나도코딩 C) 3-5 do while
# || --- 조회수 : 11000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=4eDDQU9Mwic
# ||
# || --- 영상 제목 : (나도코딩 C) 3-7 이중 반복문 파헤치기
# || --- 조회수 : 19000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=4gV1MjGIL3E
# ||
# || --- 영상 제목 : (나도코딩 C) 3-1 피라미드를 쌓아라
# || --- 조회수 : 16000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=5Xx6tK6HWGs
# ||
# || --- 영상 제목 : (나도코딩 C) 3-2 뿔뿔증감연산
# || --- 조회수 : 16000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=9n0nv27dxcs
# ||
# || --- 영상 제목 : (나도코딩 C) 3-9 프로젝트
# || --- 조회수 : 13000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=H8-sbBu0blU
# ||
# || --- 영상 제목 : (나도코딩 C) 3-6 이중 반복문 (구구단)
# || --- 조회수 : 15000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=P448GE1UGbQ
# ||
# || --- 영상 제목 : (나도코딩 C) 3-4 while
# || --- 조회수 : 12000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=Um-61He4Lhw
# ||
# || --- 영상 제목 : (나도코딩 C) 3-3 for
# || --- 조회수 : 13000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=XhoKhevLtmk
# ||
# || --- 영상 제목 : (나도코딩 C) 3-8 이중 반복문 (거꾸로 별)
# || --- 조회수 : 15000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=jjIgIPMwgLA
# ||
# || --- 영상 제목 : (나도코딩 C) 4-1 숫자 맞히기 Up&Down
# || --- 조회수 : 10000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=62pWle2i3ek
# ||
# || --- 영상 제목 : (나도코딩 C) 4-2 If Else
# || --- 조회수 : 10000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=9dxy-eG8gvI
# ||
# || --- 영상 제목 : (나도코딩 C) 4-4 And Or 연산
# || --- 조회수 : 7900
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=LjP9HlJBQ6s
# ||
# || --- 영상 제목 : (나도코딩 C) 4-5 Switch Case
# || --- 조회수 : 10000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=NJpK3RgKDS8
# ||
# || --- 영상 제목 : (나도코딩 C) 4-3 Break Continue
# || --- 조회수 : 9300
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=T-IiUqRbeu4
# ||
# || --- 영상 제목 : (나도코딩 C) 4-6 프로젝트
# || --- 조회수 : 9200
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=QEQtFN2m2G4
# ||
# || --- 영상 제목 : (나도코딩 C) 5-9 함수를 이용한 계산기
# || --- 조회수 : 8100
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=1Hbw87QrP54
# ||
# || --- 영상 제목 : (나도코딩 C) 5-10 프로젝트
# || --- 조회수 : 8500
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=3L8WqhdIF0I
# ||
# || --- 영상 제목 : (나도코딩 C) 5-7 전달값이 있는 함수
# || --- 조회수 : 6300
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=AtzogzNw5EA
# ||
# || --- 영상 제목 : (나도코딩 C) 5-6 전달값이 없는 함수
# || --- 조회수 : 6700
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=VAGucb4u_QE
# ||
# || --- 영상 제목 : (나도코딩 C) 5-2 계산기
# || --- 조회수 : 10000
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=hL3AjJX-bY8
# ||
# || --- 영상 제목 : (나도코딩 C) 5-4 반환값이 없는 함수
# || --- 조회수 : 8200
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=k5F7f3AvHZY
# ||
# || --- 영상 제목 : (나도코딩 C) 5-5 반환값이 있는 함수
# || --- 조회수 : 7600
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=qi4kIgEVqX4
# ||
# || --- 영상 제목 : (나도코딩 C) 5-3 함수의 형태
# || --- 조회수 : 8900
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=x-J-wWFBDtY
# ||
# || --- 영상 제목 : (나도코딩 C) 5-8 반환값과 전달값이 있는 함수
# || --- 조회수 : 6400
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=zsr5u4gI7Zo
# ||
# || --- 영상 제목 : (나도코딩 C) 6-6 아스키 코드
# || --- 조회수 : 6200
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=-brVtblamCY
# ||
# || --- 영상 제목 : (나도코딩 C) 6-1 아빠는 대머리
# || --- 조회수 : 7800
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=5VIDqDdKDsw
# ||
# || --- 영상 제목 : (나도코딩 C) 6-3 값 설정
# || --- 조회수 : 6700
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=6B-Vu7Ox7zQ
# ||
# || --- 영상 제목 : (나도코딩 C) 6-4 문자 vs 문자열
# || --- 조회수 : 6700
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=CXi3CykWah8
# ||
# || --- 영상 제목 : (나도코딩 C) 6-5 문자열 심화
# || --- 조회수 : 6300
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=MxUudXTn-2E
# ||
# || --- 영상 제목 : (나도코딩 C) 6-7 프로젝트
# || --- 조회수 : 8600
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=W1b7YhFjc70
# ||
# || --- 영상 제목 : (나도코딩 C) 6-2 배열 기초
# || --- 조회수 : 8400
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=pr0r_dZht0g
# ||
# || --- 영상 제목 : (나도코딩 C) 7-6 Swap
# || --- 조회수 : 6300
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=CchtxFktL4k
# ||
# || --- 영상 제목 : (나도코딩 C) 7-4 스파이(또다른 포인터)의 등장
# || --- 조회수 : 6500
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=Ij_XVWDRznI
# ||
# || --- 영상 제목 : (나도코딩 C) 7-5 배열과 포인터의 관계
# || --- 조회수 : 8900
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=MizWzX-mKfg
# ||
# || --- 영상 제목 : (나도코딩 C) 7-10 프로젝트(연장전)
# || --- 조회수 : 4700
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=QePj1QvLhcc
# ||
# || --- 영상 제목 : (나도코딩 C) 7-9 프로젝트(후반전)
# || --- 조회수 : 4700
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=S88l4zJmkNM
# ||
# || --- 영상 제목 : (나도코딩 C) 7-1 물고기 키우기
# || --- 조회수 : 8100
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=W1zcOFCGqxQ
# ||
# || --- 영상 제목 : (나도코딩 C) 7-3 미션맨(포인터)의 등장
# || --- 조회수 : 7600
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=X1LEhWth4X8
# ||
# || --- 영상 제목 : (나도코딩 C) 7-8 프로젝트(전반전)
# || --- 조회수 : 7400
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=_NIkHRkRTG4
# ||
# || --- 영상 제목 : (나도코딩 C) 7-7 포인터로 배열 값 변경하기
# || --- 조회수 : 5800
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=jYbFtxbWAzA
# ||
# || --- 영상 제목 : (나도코딩 C) 7-2 친구들의 주소
# || --- 조회수 : 7700
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=IxhMzEYB9L0
# ||
# || --- 영상 제목 : (나도코딩 C) 8-6 프로젝트(전반전)
# || --- 조회수 : 4900
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=2Zxp1eCv2-M
# ||
# || --- 영상 제목 : (나도코딩 C) 8-3 다차원 배열 접근
# || --- 조회수 : 3800
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=3SUa32DdMrI
# ||
# || --- 영상 제목 : (나도코딩 C) 8-1 동물 뒤집기
# || --- 조회수 : 4900
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=4iswgYTDJkg
# ||
# || --- 영상 제목 : (나도코딩 C) 8-4 다차원 배열 선언
# || --- 조회수 : 3600
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=DdW4-IsWa0U
# ||
# || --- 영상 제목 : (나도코딩 C) 8-5 다차원 배열 사용
# || --- 조회수 : 3800
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=N_v3MuuEikw
# ||
# || --- 영상 제목 : (나도코딩 C) 8-7 프로젝트(후반전)
# || --- 조회수 : 3800
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=_gjGH-ng2RI
# ||
# || --- 영상 제목 : (나도코딩 C) 8-8 프로젝트(연장전)
# || --- 조회수 : 4300
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=romtC4SjzjM
# ||
# || --- 영상 제목 : (나도코딩 C) 8-2 다차원 배열 기본
# || --- 조회수 : 4400
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=tdXf0fto6GA
# ||
# || --- 영상 제목 : (나도코딩 C) 9-9 프로젝트(후반전)
# || --- 조회수 : 3300
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=-0V5KtSpGeI
# ||
# || --- 영상 제목 : (나도코딩 C) 9-6 구조체 안의 구조체
# || --- 조회수 : 3700
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=UN1L207jDOg
# ||
# || --- 영상 제목 : (나도코딩 C) 9-2 구조체 기본
# || --- 조회수 : 5100
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=ecDDJ28U4BQ
# ||
# || --- 영상 제목 : (나도코딩 C) 9-7 typedef
# || --- 조회수 : 3900
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=65Fz_9-bmSQ
# ||
# || --- 영상 제목 : (나도코딩 C) 9-3 구조체 사용
# || --- 조회수 : 4400
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=NG1mbDJMRVs
# ||
# || --- 영상 제목 : (나도코딩 C) 9-1 너, 내 집사가 되어라
# || --- 조회수 : 4500
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=ZAqVsA32E_I
# ||
# || --- 영상 제목 : (나도코딩 C) 9-5 구조체 포인터
# || --- 조회수 : 4500
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=dfF43dnlr5A
# ||
# || --- 영상 제목 : (나도코딩 C) 9-4 구조체 배열
# || --- 조회수 : 4100
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=kbXED9LvMxw
# ||
# || --- 영상 제목 : (나도코딩 C) 9-8 프로젝트(전반전)
# || --- 조회수 : 3600
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=tFnJ3L4_A0I
# ||
# || --- 영상 제목 : (나도코딩 C) 10-1 비밀 일기
# || --- 조회수 : 4500
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=3hg0kSQKIuc
# ||
# || --- 영상 제목 : (나도코딩 C) 10-6 프로젝트(전반전)
# || --- 조회수 : 4100
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=9uD13421HRU
# ||
# || --- 영상 제목 : (나도코딩 C) 10-3 파일 읽기 fgets
# || --- 조회수 : 4400
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=PwZPUBw6RWA
# ||
# || --- 영상 제목 : (나도코딩 C) 10-2 파일 쓰기 fputs
# || --- 조회수 : 4700
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=SXj2RUlplNk
# ||
# || --- 영상 제목 : (나도코딩 C) 10-4 또다른 파일 쓰기 fprintf
# || --- 조회수 : 3400
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=kxZ61zgX0Kc
# ||
# || --- 영상 제목 : (나도코딩 C) 10-5 또다른 파일 읽기 fscanf
# || --- 조회수 : 3900
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=jA7Squ3JGls
# ||
# || --- 영상 제목 : [마지막] (나도코딩 C) 10-7 프로젝트(후반전)
# || --- 조회수 : 6300
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=xZP-ssNpQOU
# ||
# || --- 영상 제목 : (나도코딩 C) 5-1 비밀번호 마스터
# || --- 조회수 : 9900
# || --- 업로드 날짜 : 6년 전
# || --- 링크 : https://www.youtube.com/watch?v=hwerIdYt_Mo
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 소개 - 입문부터 실전 게임 개발까지
# || --- 조회수 : 41000
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=xN8O_mhR-7Y
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 1-1.스크래치란 무엇인가?
# || --- 조회수 : 21000
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=QrqkDIftMec
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 1-2.스크래치 환경 설정 방법 (2.0 과 3.0 통합)
# || --- 조회수 : 10000
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=5yYJi9iLjSM
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 1-3.스크래치 2.0 vs 3.0, 어떻게 달라졌을까? 기본 화면 완벽 비교
# || --- 조회수 : 8300
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=rGYBwTcpUbk
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 2-1.스크립트 맛보기
# || --- 조회수 : 7800
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=hhRvYCs2f-I
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 2-2.댄스 댄스
# || --- 조회수 : 8400
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=t0igY575QJs
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 3.고양이와 쥐
# || --- 조회수 : 10000
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=j499B4IgR8k
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 4.상어 피하기
# || --- 조회수 : 15000
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=_IPilAXAknM
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 5.혈액형별 성격 알아보기
# || --- 조회수 : 5700
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=i3Xr_EaQHeA
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 6-4.피아노 연주 스크립트 만들기
# || --- 조회수 : 4600
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=Vc_BQJ0i-LQ
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 6-2.음악 스크립트 기초
# || --- 조회수 : 4000
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=rHG7eJN-tPM
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 6-3.음표와 박자 알아보기
# || --- 조회수 : 2800
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=yoVBgxHWNZ0
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 6-1.어거스트 러쉬 ost 피아노 연주 프로젝트
# || --- 조회수 : 4400
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=jdSanTvVPUg
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 7-2.일단 공 움직여 보기
# || --- 조회수 : 3400
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=LCu3yVRXRG8
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 7-3.조건에 따라 공 움직이기
# || --- 조회수 : 3700
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=LDslo0v-Lh8
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 7-1.당구의 신 - 큐대 만들기
# || --- 조회수 : 4900
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=fH2a3ErDAyU
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 8-1.장난꾸러기 고스트 - 친구가 군대에서 겪은 귀신이야기
# || --- 조회수 : 2500
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=-7CeuaHNK-E
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 8-2.무대를 스프라이트로 사용하기(스크래치 2.0)
# || --- 조회수 : 2500
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=FX1n7E3InH8
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 8-3.무대를 스프라이트로 사용하기(스크래치 3.0)
# || --- 조회수 : 2700
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=4tHJCN8HoAI
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 8-4.진짜 게임처럼 움직이는 배경 만들기
# || --- 조회수 : 8300
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=Q9-vGGa34U8
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 8-5.둥둥 떠있는 고스트 만들기
# || --- 조회수 : 3000
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=-m7LhoG0vSE
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 8-6.도망치는 제이미 만들기
# || --- 조회수 : 2800
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=MSPJr866N-o
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 8-7.고스트와 제이미 충돌처리
# || --- 조회수 : 2000
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=owxHvlfiQx0
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 8-8.게임 종료 방송하기
# || --- 조회수 : 2200
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=6TuJgcdMNcw
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 8-9.내 목소리를 제이미가 듣는다구?? 소리를 질러서 제이미를 도와주세요!!
# || --- 조회수 : 2400
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=9d-2QHftlWU
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 9-1.실전 프로젝트 준비! 무료 이미지 편집 프로그램 Pixlr 소개
# || --- 조회수 : 3300
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=VVl3KMJMz6c
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 9-2.우주선 이미지 따오기 연습
# || --- 조회수 : 2900
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=Xh-VrsfpJ_I
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 9-3.총알 이미지 따오기 연습
# || --- 조회수 : 2000
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=CD_xSVc3Nzs
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 9-4.무료 이미지 제공 사이트 FreePik 소개
# || --- 조회수 : 2100
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=zH0u58sfaPc
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 10-1.선생님은 결국 해내지 못했습니다. 누구든지 1분 이상 버티면 인정! 총알피하기 게임 (실전 프로젝트 #1)
# || --- 조회수 : 3300
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=iwIDc8DfpYw
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 10-2.방향키로 우주선 이동하기
# || --- 조회수 : 3000
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=8Y9pUnLD-g0
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 10-3.사방에서 날아오는 총알 만들기
# || --- 조회수 : 3600
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=OErX4NYoZkk
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 10-4.총알 충돌 처리
# || --- 조회수 : 2100
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=oL_Lhn1qc18
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 10-5.생존시간 측정
# || --- 조회수 : 3900
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=qqkNlzlt5Qo
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 11-1.똥이 무서워서 피하나, 더러워서 피하지! 똥피하기 게임 (실전 프로젝트 #2)
# || --- 조회수 : 3900
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=Cb4zOpKM_FU
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 11-3.캐릭터 좌우로 이동하기
# || --- 조회수 : 3700
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=HT7PfAeX2as
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 11-6.동전 점수 계산하기
# || --- 조회수 : 2200
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=BZVurS5vbBg
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 11-7.똥 충돌 처리하기
# || --- 조회수 : 2100
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=DAVRfAGigVI
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 11-2.게임 이미지 준비하기
# || --- 조회수 : 2600
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=FSru026rMgI
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 11-5.동전 떨어트리기
# || --- 조회수 : 2500
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=LBRLIeSuT_g
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 11-4.똥 떨어트리기
# || --- 조회수 : 3600
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=MltFJDXkBOw
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 12-1.지금까지 이런 게임은 없었다. 4차원 병맛 퀴즈! 두뇌풀가동 게임 (실전 프로젝트 #3)
# || --- 조회수 : 2800
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=8E7dPaP7fYU
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 12-4.캐릭터 이동하기
# || --- 조회수 : 1500
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=0fzG80T0op8
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 12-2.게임 이미지 준비하기
# || --- 조회수 : 1800
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=5C1W6KLqtJU
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 12-3.다가오는 벽 만들기
# || --- 조회수 : 1700
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=CfXkouTLzHc
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 12-6.정답 처리 하기
# || --- 조회수 : 1400
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=IgeLSKBOyFA
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 12-5.무작위로 퀴즈 출제하기
# || --- 조회수 : 1900
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=KHXZuzqmnwE
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 12-7.게임 오버 처리 및 점수 계산하기
# || --- 조회수 : 1900
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=fKBAX8inx0c
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 12-8.게임 다듬기
# || --- 조회수 : 1100
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=zqRKDyn9Ohc
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 13-7.아이템 패턴 #1
# || --- 조회수 : 2400
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=19haD407CXg
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 13-4.쿠키걸 점프하기 - 이론편
# || --- 조회수 : 3100
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=1xd9OcUlemU
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 13-10.아이템 패턴 #3 (천장 장애물과 아이템)
# || --- 조회수 : 1700
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=8owwTZVqJhI
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 13-3.캐릭터 추가하기
# || --- 조회수 : 3200
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=CHHAf0okY-g
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 13-1.설마 이 게임을 모르는 사람은 없겠지? 쿠키런 (실전 프로젝트 #4)
# || --- 조회수 : 4200
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=CRtPuR342xY
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 13-8.아이템 패턴 #2-1 (아이템)
# || --- 조회수 : 2200
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=UL6dGh7BBQs
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 13-11.쿠키걸 충돌 시 게임오버 처리
# || --- 조회수 : 4600
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=bYSPJe1TZHE
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 13-5.쿠키걸 점프하기 - 실습편
# || --- 조회수 : 3700
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=dVWue6c1-l8
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 13-2.게임 이미지 준비 및 움직이는 배경 만들기
# || --- 조회수 : 6800
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=mKnxFDJlZLk
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 13-6.3가지 아이템 패턴 - 이론편
# || --- 조회수 : 1800
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=tp8_IF5-AHY
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 13-9.아이템 패턴 #2-2 (바닥 장애물)
# || --- 조회수 : 2100
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=xHULYVOnCi4
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-1.창과 방패의 싸움! 엄마는 게임을 숨겼다 3탄 (실전 프로젝트 #5)
# || --- 조회수 : 3200
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=IJwT-LXBLuQ
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-2.시작 화면 만들기
# || --- 조회수 : 4900
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=EtMb4CpnNTQ
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-3.기본 배경 만들기
# || --- 조회수 : 1900
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=jETgVUWs9fQ
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-4.좌우로 무대 전환하기
# || --- 조회수 : 2300
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=bWlafGBU-_M
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-5.왼쪽화면 만들기 #1 - 옷장 넣기
# || --- 조회수 : 1100
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=Kt2UewaDKVk
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-6.왼쪽화면 만들기 #2 - 창문과 커튼 달기
# || --- 조회수 : 991
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=DFGAwhKbBZk
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-7.오른쪽 화면 만들기 #1 - 벽장 넣기
# || --- 조회수 : 993
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=BBwZ5pB8hbs
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-8.오른쪽 화면 만들기 #2 - 소파와 쿠션 넣기
# || --- 조회수 : 989
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=tjN6j4OQRiU
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-9.주인공의 목표, 게임기 넣기
# || --- 조회수 : 922
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=1XmBI6o8ASQ
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-10.사다리용 벽장 넣기
# || --- 조회수 : 1000
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=A2nZNkXAnsA
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-11.스테이지에 따른 화면 배치 #1. 리스트 만들기
# || --- 조회수 : 1800
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=6cqkfAUkvHI
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-12.스테이지에 따른 화면 배치 #2. 왼쪽화면 적용하기 (옷장, 커튼)
# || --- 조회수 : 1000
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=TDNs0ofW0Po
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-13.스테이지에 따른 화면 배치 #3. 오른쪽 화면 적용하기 (벽장 소파 쿠션)
# || --- 조회수 : 1000
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=tbEdjTfI61E
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-14.소파 밑에 엄마 숨기기
# || --- 조회수 : 1300
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=5drQ4BUuIfM
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-15.스테이지1 엄마에게 들킴 (실패처리)
# || --- 조회수 : 1600
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=sCZ_xMau0uQ
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-16.스테이지1 쿠션 확인하기 (성공처리)
# || --- 조회수 : 1500
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=CBsuoKwebwc
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-17.스테이지2 사다리 이용 (성공처리)
# || --- 조회수 : 2000
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=deQzk6GeP5A
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-18.스테이지2 엄마에게 들킴 (실패처리)
# || --- 조회수 : 2200
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=Zbl0WcRqQ1Y
# ||
# || --- 영상 제목 : (나도코딩 스크래치) 14-19.(마지막 강의) 게임 오버 처리, 이 강의도 오버 처리
# || --- 조회수 : 5800
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=973ZOeyIIgU
# ||
# || --- 영상 제목 : 개발시간을 확 줄여주는 유용한 단축키 10가지
# || --- 조회수 : 40000
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=LmCFaOB4YPI
# ||
# || --- 영상 제목 : 컴퓨터로 일하시는 분들, 이건 꼭 알고 가셔야 합니다 | 업무 생산성을 높여주는 최고의 프로그램 (Notepad++)
# || --- 조회수 : 140000
# || --- 업로드 날짜 : 5년 전
# || --- 링크 : https://www.youtube.com/watch?v=r1lpBGlIzY0
# ||
# || --- 영상 제목 : 파이썬 코딩 무료 강의 (기본편) - 6시간 뒤면 여러분도 개발자가 될 수 있어요 [나도코딩]
# || --- 조회수 : 5360000
# || --- 업로드 날짜 : 4년 전
# || --- 링크 : https://www.youtube.com/watch?v=kWiCuklohdY
# ||
# || --- 영상 제목 : 파이썬 코딩 무료 강의 (활용편1) - 추억의 오락실 게임을 만들어 보아요. 3시간이면 충분합니다. [나도코딩]
# || --- 조회수 : 2980000
# || --- 업로드 날짜 : 4년 전
# || --- 링크 : https://www.youtube.com/watch?v=Dkx8Pl6QKW0
# ||
# || --- 영상 제목 : 파이썬 코딩 무료 강의 (활용편2) - GUI 프로그래밍을 배우고 '여러 이미지 합치기' 프로그램을 함께 만들어요. [나도코딩]
# || --- 조회수 : 1410000
# || --- 업로드 날짜 : 4년 전
# || --- 링크 : https://www.youtube.com/watch?v=bKPIcoou9N8
# ||
# || --- 영상 제목 : 파이썬 코딩 퀴즈 #1 (레벨 2)
# || --- 조회수 : 45000
# || --- 업로드 날짜 : 4년 전
# || --- 링크 : https://www.youtube.com/watch?v=kla7FiwnAvE
# ||
# || --- 영상 제목 : 파이썬 코딩 무료 강의 (활용편3) - 웹 크롤링? 웹 스크래핑! 제가 가진 모든 비법을 알려드리겠습니다. [나도코딩]
# || --- 조회수 : 620000
# || --- 업로드 날짜 : 4년 전
# || --- 링크 : https://www.youtube.com/watch?v=yQ20jZwDjTE
# ||
# || --- 영상 제목 : 파이썬 코딩 퀴즈 #2 (레벨 4)
# || --- 조회수 : 23000
# || --- 업로드 날짜 : 4년 전
# || --- 링크 : https://www.youtube.com/watch?v=487mr-e_Z74
# ||
# || --- 영상 제목 : 파이썬 코딩 퀴즈 #3 (레벨 1)
# || --- 조회수 : 17000
# || --- 업로드 날짜 : 4년 전
# || --- 링크 : https://www.youtube.com/watch?v=QEYIVLyGIRI
# ||
# || --- 영상 제목 : 윈도우 10 유용한 꿀팁 7 가지
# || --- 조회수 : 27000
# || --- 업로드 날짜 : 4년 전
# || --- 링크 : https://www.youtube.com/watch?v=e3PPRdxkAKs
# ||
# || --- 영상 제목 : C 언어 무료 강의 (입문부터 게임 개발까지)
# || --- 조회수 : 1820000
# || --- 업로드 날짜 : 4년 전
# || --- 링크 : https://www.youtube.com/watch?v=q6fPjQAzll8
# ||
# || --- 영상 제목 : 파이썬 프로그램을 .exe 실행 파일로 만드는 방법 (PyInstaller)
# || --- 조회수 : 150000
# || --- 업로드 날짜 : 4년 전
# || --- 링크 : https://www.youtube.com/watch?v=Es1fQqqxIFQ
# ||
# || --- 영상 제목 : 파이썬 코딩 퀴즈 #4 (레벨3)
# || --- 조회수 : 12000
# || --- 업로드 날짜 : 4년 전
# || --- 링크 : https://www.youtube.com/watch?v=btpZOB_TvQ4
# ||
# || --- 영상 제목 : 파이썬 소스코드 비교하는 방법 (vscode)
# || --- 조회수 : 38000
# || --- 업로드 날짜 : 4년 전
# || --- 링크 : https://www.youtube.com/watch?v=dWiqSYpjnxU
# ||
# || --- 영상 제목 : 파이썬 코딩 무료 강의 (활용편4) - 업무자동화(RPA), 이제는 일하는 척(?)만 하세요
# || --- 조회수 : 780000
# || --- 업로드 날짜 : 3년 전
# || --- 링크 : https://www.youtube.com/watch?v=exgO1LFl9x8
# ||
# || --- 영상 제목 : 파이썬 초보 탈출하기 #1 | 물어보기
# || --- 조회수 : 34000
# || --- 업로드 날짜 : 3년 전
# || --- 링크 : https://www.youtube.com/watch?v=LZQC9mEzdtk
# ||
# || --- 영상 제목 : 파이썬 초보 탈출하기 #2 | 디버깅 Debugging
# || --- 조회수 : 51000
# || --- 업로드 날짜 : 3년 전
# || --- 링크 : https://www.youtube.com/watch?v=_1HM6MJMYPw
# ||
# || --- 영상 제목 : 개발자도 틀리는 깜짝 퀴즈 | 해설편 | 파이썬
# || --- 조회수 : 12000
# || --- 업로드 날짜 : 3년 전
# || --- 링크 : https://www.youtube.com/watch?v=4lyg-3dvfzU
# ||
# || --- 영상 제목 : 실버 버튼을 받았습니다.
# || --- 조회수 : 11000
# || --- 업로드 날짜 : 3년 전
# || --- 링크 : https://www.youtube.com/watch?v=x2OJ1otOC3o
# ||
# || --- 영상 제목 : 파이썬 초보 탈출하기 #3 | 구글링 Googling
# || --- 조회수 : 53000
# || --- 업로드 날짜 : 3년 전
# || --- 링크 : https://www.youtube.com/watch?v=PEtjVQa_LEA
# ||
# || --- 영상 제목 : 파이썬 실전 프로젝트 | 기억력 테스트 게임, 침팬지를 이겨라
# || --- 조회수 : 87000
# || --- 업로드 날짜 : 3년 전
# || --- 링크 : https://www.youtube.com/watch?v=Qsk-xsi73YA
# ||
# || --- 영상 제목 : 파이썬 실전 프로젝트 | 황금캐기 게임 개발
# || --- 조회수 : 220000
# || --- 업로드 날짜 : 3년 전
# || --- 링크 : https://www.youtube.com/watch?v=sf5TmP137IM
# ||
# || --- 영상 제목 : 파이썬 실전 프로젝트 | 퍼즐 보블 오락실 게임 (Puzzle Bobble)
# || --- 조회수 : 300000
# || --- 업로드 날짜 : 3년 전
# || --- 링크 : https://www.youtube.com/watch?v=f1amAQuVtc8
# ||
# || --- 영상 제목 : [신청 마감] 인공지능, 처음부터 제대로 공부하실 분?
# || --- 조회수 : 60000
# || --- 업로드 날짜 : 3년 전
# || --- 링크 : https://www.youtube.com/watch?v=wITS80U_jbk
# ||
# || --- 영상 제목 : 아나콘다 환경 설정 및 주피터 노트북 사용법
# || --- 조회수 : 150000
# || --- 업로드 날짜 : 3년 전
# || --- 링크 : https://www.youtube.com/watch?v=dJfq-eCi7KI
# ||
# || --- 영상 제목 : 파이썬 코딩 무료 강의 (활용편5) - 데이터 분석 및 시각화, 이 영상 하나로 끝내세요
# || --- 조회수 : 410000
# || --- 업로드 날짜 : 3년 전
# || --- 링크 : https://www.youtube.com/watch?v=PjhlUzp_cU0
# ||
# || --- 영상 제목 : [신청 마감] 인공지능 3대 기술 배우실 분을 찾습니다. [부스트캠프 AI Tech 3기 모집중!]
# || --- 조회수 : 30000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=5n3uSXM2kU4
# ||
# || --- 영상 제목 : 파이썬 코딩 무료 강의 (활용편6) - OpenCV 이미지 처리, 얼굴 인식을 통한 캐릭터 씌우기를 해보아요
# || --- 조회수 : 250000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=XK3eU9egll8
# ||
# || --- 영상 제목 : 첫 구독자 이벤트! 파이썬으로 웹 이미지 다운로드 자동화하기 (BenQ 27인치 모니터 드립니다. 지금 바로 신청하세요!)
# || --- 조회수 : 18000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=ZylRBW6tL-I
# ||
# || --- 영상 제목 : 1분 파이썬 - (1) 소개
# || --- 조회수 : 50000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=sj4vexbygKA
# ||
# || --- 영상 제목 : 1분 파이썬 - (2) 환경설정
# || --- 조회수 : 37000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=2G5BARng9JM
# ||
# || --- 영상 제목 : 1분 파이썬 - (3) 자료형
# || --- 조회수 : 34000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=kr-uIzwVcv8
# ||
# || --- 영상 제목 : 1분 파이썬 - (4) 변수
# || --- 조회수 : 30000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=9pMq-EjIalo
# ||
# || --- 영상 제목 : 1분 파이썬 - (5) 변수 이름
# || --- 조회수 : 24000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=th23PxXSYpY
# ||
# || --- 영상 제목 : 1분 파이썬 - (6) 형 변환
# || --- 조회수 : 23000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=9CqIHmzP-Q0
# ||
# || --- 영상 제목 : 1분 파이썬 - (7) 연산자
# || --- 조회수 : 24000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=XlrRQXP9GD0
# ||
# || --- 영상 제목 : 1분 파이썬 - (8) 불리안
# || --- 조회수 : 17000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=LUCpzIZJ4YA
# ||
# || --- 영상 제목 : 1분 파이썬 - (9) 주석
# || --- 조회수 : 16000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=9E84YWmr948
# ||
# || --- 영상 제목 : 1분 파이썬 - (10) 인덱스와 슬라이싱
# || --- 조회수 : 24000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=LC5gZ9O7-YU
# ||
# || --- 영상 제목 : 1분 파이썬 - (11) 문자열 처리
# || --- 조회수 : 20000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=j06b2RdJB-s
# ||
# || --- 영상 제목 : 1분 파이썬 - (12) 문자열 메소드 1
# || --- 조회수 : 16000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=GnI4_8ZeYaU
# ||
# || --- 영상 제목 : 1분 파이썬 - (13) 문자열 메소드 2
# || --- 조회수 : 13000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=V0dZucvVwho
# ||
# || --- 영상 제목 : 1분 파이썬 - (14) 문자열 포맷
# || --- 조회수 : 16000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=QqOgNyZ16R0
# ||
# || --- 영상 제목 : 1분 파이썬 - (15) 탈출 문자
# || --- 조회수 : 13000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=jCSEElJDixk
# ||
# || --- 영상 제목 : 1분 파이썬 - (16) 리스트 1
# || --- 조회수 : 21000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=uxf4cTeonY4
# ||
# || --- 영상 제목 : 1분 파이썬 - (17) 리스트 2
# || --- 조회수 : 17000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=KEhPKBpPJvI
# ||
# || --- 영상 제목 : 1분 파이썬 - (18) 튜플 1
# || --- 조회수 : 15000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=zNzbD_oJ9Vo
# ||
# || --- 영상 제목 : 네이버 항공권 웹 자동화 (22년 최신 페이지 반영)
# || --- 조회수 : 18000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=aIxdWfCe8Fo
# ||
# || --- 영상 제목 : 1분 파이썬 - (19) 튜플 2
# || --- 조회수 : 12000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=ncQBBcwQEso
# ||
# || --- 영상 제목 : 집중력이 필요할 때 들어요 (스타벅스 카페 백색소음 ASMR 3시간)
# || --- 조회수 : 5700
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=PioVE6ZLVOs
# ||
# || --- 영상 제목 : 1분 파이썬 - (20) 세트 1
# || --- 조회수 : 12000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=poqZPwrBAec
# ||
# || --- 영상 제목 : 1분 파이썬 - (21) 세트 2
# || --- 조회수 : 10000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=dJHiMzWFMwI
# ||
# || --- 영상 제목 : 1분 파이썬 - (22) 딕셔너리 1
# || --- 조회수 : 15000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=ZLp_Wg6VxfA
# ||
# || --- 영상 제목 : 1분 파이썬 - (23) 딕셔너리 2
# || --- 조회수 : 12000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=LV4IQnllYBA
# ||
# || --- 영상 제목 : 1분 파이썬 - (24) 자료형 비교
# || --- 조회수 : 10000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=y7HC83jj76o
# ||
# || --- 영상 제목 : 1분 파이썬 - (25) 자료형 변환
# || --- 조회수 : 9500
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=H3uTdIg0VdU
# ||
# || --- 영상 제목 : 1분 파이썬 - (26) if 조건문 1
# || --- 조회수 : 18000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=N92M3WaLbH0
# ||
# || --- 영상 제목 : 1분 파이썬 - (27) if 조건문 2
# || --- 조회수 : 12000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=J9srd8Mfoyc
# ||
# || --- 영상 제목 : 1분 파이썬 - (28) if 중첩
# || --- 조회수 : 14000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=eGEg98j4JQw
# ||
# || --- 영상 제목 : 1분 파이썬 - (29) for 반복문
# || --- 조회수 : 29000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=uecZdRyiFNA
# ||
# || --- 영상 제목 : 1분 파이썬 - (30) range
# || --- 조회수 : 15000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=sJrv25QnRFk
# ||
# || --- 영상 제목 : 1분 파이썬 - (31) for 활용
# || --- 조회수 : 12000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=93_2E88rvDY
# ||
# || --- 영상 제목 : 1분 파이썬 - (32) while
# || --- 조회수 : 17000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=HgylrKz95tQ
# ||
# || --- 영상 제목 : 1분 파이썬 - (33) break
# || --- 조회수 : 10000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=9m93pYaT0rA
# ||
# || --- 영상 제목 : 1분 파이썬 - (34) continue
# || --- 조회수 : 9600
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=ACTM_7mwbr0
# ||
# || --- 영상 제목 : 1분 파이썬 - (35) 들여쓰기
# || --- 조회수 : 8600
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=LC0Fe_9bmhs
# ||
# || --- 영상 제목 : 1분 파이썬 - (36) 리스트 컴프리헨션
# || --- 조회수 : 11000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=3wN0eVDhrvE
# ||
# || --- 영상 제목 : 1분 파이썬 - (37) 함수
# || --- 조회수 : 18000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=YTEr1VTbe4Q
# ||
# || --- 영상 제목 : 1분 파이썬 - (38) 전달값
# || --- 조회수 : 10000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=GCMrf7wThT4
# ||
# || --- 영상 제목 : 1분 파이썬 - (39) 반환값
# || --- 조회수 : 10000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=DhBNQ4RqQQY
# ||
# || --- 영상 제목 : 1분 파이썬 - (40) 기본값
# || --- 조회수 : 7700
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=oM-MBmAvYkM
# ||
# || --- 영상 제목 : 1분 파이썬 - (41) 키워드값
# || --- 조회수 : 7600
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=mrg3c2xT9Mw
# ||
# || --- 영상 제목 : 1분 파이썬 - (42) 가변인자
# || --- 조회수 : 8900
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=1KjurNirq1I
# ||
# || --- 영상 제목 : 1분 파이썬 - (43) 지역변수
# || --- 조회수 : 9500
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=bLJf0rnEdqU
# ||
# || --- 영상 제목 : 1분 파이썬 - (44) 전역변수
# || --- 조회수 : 10000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=lMeKbV8FOX8
# ||
# || --- 영상 제목 : 1분 파이썬 - (45) 사용자입력
# || --- 조회수 : 9600
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=ZJYrhYqwMAg
# ||
# || --- 영상 제목 : 1분 파이썬 - (46) 파일입출력
# || --- 조회수 : 13000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=2JQ24B3OVZU
# ||
# || --- 영상 제목 : 1분 파이썬 - (47) with
# || --- 조회수 : 9900
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=o1sTax907Dc
# ||
# || --- 영상 제목 : 1분 파이썬 - (48) 클래스
# || --- 조회수 : 17000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=8SaxeSD6M0M
# ||
# || --- 영상 제목 : 1분 파이썬 - (49) 클래스 정의
# || --- 조회수 : 13000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=a_PgyLjEL2A
# ||
# || --- 영상 제목 : 파이썬 코딩 무료 강의 (활용편7) - 머신러닝, 영화 추천 시스템 만들기
# || --- 조회수 : 210000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=TNcfJHajqJY
# ||
# || --- 영상 제목 : 1분 파이썬 - (50) __init__
# || --- 조회수 : 16000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=V7QVHdapD7M
# ||
# || --- 영상 제목 : 1분 파이썬 - (51) 멤버변수
# || --- 조회수 : 9000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=ysoxUEhOz3w
# ||
# || --- 영상 제목 : 1분 파이썬 - (52) 메소드
# || --- 조회수 : 11000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=JZ-cRMCmatU
# ||
# || --- 영상 제목 : 1분 파이썬 - (53) self
# || --- 조회수 : 12000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=5_L0d3A1-5o
# ||
# || --- 영상 제목 : 1분 파이썬 - (54) 상속
# || --- 조회수 : 10000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=AQT_nfRV4TY
# ||
# || --- 영상 제목 : 1분 파이썬 - (55) super
# || --- 조회수 : 9600
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=w9b4DEJhw5k
# ||
# || --- 영상 제목 : 1분 파이썬 - (56) 다중상속
# || --- 조회수 : 7400
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=BRz95yhOtfs
# ||
# || --- 영상 제목 : 1분 파이썬 - (57) 메소드 오버라이딩
# || --- 조회수 : 8200
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=wj_bkxAozgs
# ||
# || --- 영상 제목 : 1분 파이썬 - (58) pass
# || --- 조회수 : 5900
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=1jzANozfx4c
# ||
# || --- 영상 제목 : 1분 파이썬 - (59) 예외처리
# || --- 조회수 : 7800
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=FFuubo7JXOU
# ||
# || --- 영상 제목 : 1분 파이썬 - (60) 에러
# || --- 조회수 : 7200
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=XFYGmzMzaHU
# ||
# || --- 영상 제목 : 1분 파이썬 - (61) 모듈
# || --- 조회수 : 14000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=pVSS02HUnRA
# ||
# || --- 영상 제목 : (마지막) 1분 파이썬 - (62) 패키지
# || --- 조회수 : 9800
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=5IepQgKWT6U
# ||
# || --- 영상 제목 : [신청 마감] 인공지능 교육을 찾고 계신가요? 이것을 추천 드립니다.
# || --- 조회수 : 11000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=cEMz2rqjpw4
# ||
# || --- 영상 제목 : 파이썬 무료 강의 100분 완성 (1분 파이썬 모음)
# || --- 조회수 : 610000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=T6z-0dpXPvU
# ||
# || --- 영상 제목 : Mac 에서 C 언어 개발 환경설정 | Xcode 편
# || --- 조회수 : 18000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=RIe_PMUGEuU
# ||
# || --- 영상 제목 : Mac 에서 C 언어 개발 환경설정 | Visual Studio Code 편
# || --- 조회수 : 65000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=ix7K3xMudgc
# ||
# || --- 영상 제목 : 파이썬 가상환경 사용 방법 (중요) | venv
# || --- 조회수 : 71000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=o_vKT80BBkw
# ||
# || --- 영상 제목 : 틀린그림찾기 자동화 【파이썬】
# || --- 조회수 : 53000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=IfjL4HXECFA
# ||
# || --- 영상 제목 : 주식정보 크롤링하기 【파이썬】
# || --- 조회수 : 78000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=ZDh1C7qw0Rs
# ||
# || --- 영상 제목 : 인공지능 스피커 만들기 【파이썬】
# || --- 조회수 : 62000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=WTul6LIjIBA
# ||
# || --- 영상 제목 : 【C 언어 입문 책】 소개 드립니다
# || --- 조회수 : 22000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=VUuKCfQPzic
# ||
# || --- 영상 제목 : C 언어 셀프체크 2장 풀이 【코딩 자율학습, 나도코딩의 C 언어 입문】
# || --- 조회수 : 14000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=dv1gMvlmb1M
# ||
# || --- 영상 제목 : C 언어 셀프체크 3장 풀이 【코딩 자율학습, 나도코딩의 C 언어 입문】
# || --- 조회수 : 4700
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=KoxP33Ewj5o
# ||
# || --- 영상 제목 : C 언어 셀프체크 4장 풀이 【코딩 자율학습, 나도코딩의 C 언어 입문】
# || --- 조회수 : 3800
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=Dc0Ecxcagik
# ||
# || --- 영상 제목 : C 언어 셀프체크 5장 풀이 【코딩 자율학습, 나도코딩의 C 언어 입문】
# || --- 조회수 : 3000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=HZl6EPzuLvc
# ||
# || --- 영상 제목 : 공공데이터를 활용한 우리 동네 아파트 실거래가 분석
# || --- 조회수 : 29000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=31EX6TLao5g
# ||
# || --- 영상 제목 : C 언어 셀프체크 6장 풀이 【코딩 자율학습, 나도코딩의 C 언어 입문】
# || --- 조회수 : 3200
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=FqLN-7gXnB8
# ||
# || --- 영상 제목 : C 언어 셀프체크 7장 풀이 【코딩 자율학습, 나도코딩의 C 언어 입문】
# || --- 조회수 : 2900
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=MkxeDDHuFG0
# ||
# || --- 영상 제목 : C 언어 셀프체크 8장 풀이 【코딩 자율학습, 나도코딩의 C 언어 입문】
# || --- 조회수 : 3000
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=5dm18-y5PtU
# ||
# || --- 영상 제목 : C 언어 셀프체크 9장 풀이 【코딩 자율학습, 나도코딩의 C 언어 입문】
# || --- 조회수 : 3100
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=-KT67Fpro8o
# ||
# || --- 영상 제목 : C 언어 셀프체크 10장 풀이 【코딩 자율학습, 나도코딩의 C 언어 입문】
# || --- 조회수 : 3800
# || --- 업로드 날짜 : 2년 전
# || --- 링크 : https://www.youtube.com/watch?v=ToMpsRafTpw
# ||
# || --- 영상 제목 : 인공지능 고구마 판별기 만들기
# || --- 조회수 : 13000
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=j8Nj7NYqYB4
# ||
# || --- 영상 제목 : ChatGPT, 개발의 새로운 장을 여네요 (무료일 때 꼭 경험해보세요)
# || --- 조회수 : 440000
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=VbqbnO8n48w
# ||
# || --- 영상 제목 : 자바 코딩 무료 강의 (기본편) - 9시간 뒤면 여러분도 개발자가 될 수 있어요
# || --- 조회수 : 510000
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=NQq0dOoEPUM
# ||
# || --- 영상 제목 : 1인 게임 개발을 꿈꾸는 이들에게
# || --- 조회수 : 220000
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=OLGX_XtX7Fc
# ||
# || --- 영상 제목 : 【파이썬 입문 책】 소개 드립니다
# || --- 조회수 : 16000
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=RAW2WaTg6P4
# ||
# || --- 영상 제목 : 파이썬 셀프체크 2장 풀이 【코딩 자율학습, 나도코딩의 파이썬 입문】
# || --- 조회수 : 11000
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=6Nzz4xkhaZQ
# ||
# || --- 영상 제목 : 파이썬 셀프체크 3장 풀이 【코딩 자율학습, 나도코딩의 파이썬 입문】
# || --- 조회수 : 4100
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=yJf9uF3rx0I
# ||
# || --- 영상 제목 : 파이썬 셀프체크 4장 풀이 【코딩 자율학습, 나도코딩의 파이썬 입문】
# || --- 조회수 : 3000
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=pp_lH-0pYXY
# ||
# || --- 영상 제목 : 파이썬 셀프체크 5장 풀이 【코딩 자율학습, 나도코딩의 파이썬 입문】
# || --- 조회수 : 2500
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=FCpY7qRsK9w
# ||
# || --- 영상 제목 : 파이썬 셀프체크 6장 풀이 【코딩 자율학습, 나도코딩의 파이썬 입문】
# || --- 조회수 : 2500
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=0HNZ_2A38Y0
# ||
# || --- 영상 제목 : 파이썬 셀프체크 7장 풀이 【코딩 자율학습, 나도코딩의 파이썬 입문】
# || --- 조회수 : 2400
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=y1vP1bFGPog
# ||
# || --- 영상 제목 : 파이썬 셀프체크 8장 풀이 【코딩 자율학습, 나도코딩의 파이썬 입문】
# || --- 조회수 : 2300
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=DTlnYhg1hGY
# ||
# || --- 영상 제목 : 유니티 게임 개발 100강사전 오픈
# || --- 조회수 : 8700
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=rllW-8WmQzI
# ||
# || --- 영상 제목 : 파이썬 셀프체크 9장 풀이 【코딩 자율학습, 나도코딩의 파이썬 입문】
# || --- 조회수 : 2500
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=WCc84WZPnKw
# ||
# || --- 영상 제목 : 파이썬 셀프체크 10장 풀이 【코딩 자율학습, 나도코딩의 파이썬 입문】
# || --- 조회수 : 2400
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=7Ef-y8Nb5A8
# ||
# || --- 영상 제목 : 파이썬 셀프체크 11장 풀이 【코딩 자율학습, 나도코딩의 파이썬 입문】
# || --- 조회수 : 3900
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=ZNT770WCv5M
# ||
# || --- 영상 제목 : 유니티 무료 강의 (Crash Course) - 5시간 만에 게임 만드는 법 배우기
# || --- 조회수 : 370000
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=rJE6bhVUNhk
# ||
# || --- 영상 제목 : 5000만 다운로드 게임 aa 만들기 - 유니티 게임개발 무료 강의 (실전 프로젝트1)
# || --- 조회수 : 26000
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=g3xKeBkGGRU
# ||
# || --- 영상 제목 : 무조건 유용한 기억력 테스트 게임 - 유니티 게임개발 무료 강의 (실전 프로젝트2)
# || --- 조회수 : 27000
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=XhfB3ZS3JoM
# ||
# || --- 영상 제목 : 초보자를 위한 코딩 공부 방법 (없어지기 전에 빨리 보세요) #유데미
# || --- 조회수 : 59000
# || --- 업로드 날짜 : 1년 전
# || --- 링크 : https://www.youtube.com/watch?v=DPdKIOolNFo
# ||
# || --- 영상 제목 : 새로운 시작, 코딩 공부와 함께 #유데미
# || --- 조회수 : 8600
# || --- 업로드 날짜 : 10개월 전
# || --- 링크 : https://www.youtube.com/watch?v=JhsrCJ_Hb84
# ||
# || --- 영상 제목 : 자바 무료 강의 2시간 완성 (1분 자바)
# || --- 조회수 : 50000
# || --- 업로드 날짜 : 6개월 전
# || --- 링크 : https://www.youtube.com/watch?v=DNCBaeCoMug
# ||
# || --- 영상 제목 : 챗GPT4o with Canvas 소개 - 글쓰기 및 코딩하시는 분들 꼭 보세요
# || --- 조회수 : 30000
# || --- 업로드 날짜 : 1개월 전
# || --- 링크 : https://www.youtube.com/watch?v=_QPdytD9yXY
# ||
